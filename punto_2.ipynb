# %% [markdown]
# ##Luis López A00405100, Wilde Garcia A00405204
# #Algunas graficas del 2 punto (la verdadera solucion esta en latex, se podria decir)
# ###Para el grafico k se tuvo que definir desde 2. (con 1 da raiz de un numero negativo)
# ###cuando se define para n>=0 : list(range(50)), cuando se define para n>=1 , list(range(1, 50).

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# Crear una figura y una cuadrícula de subgráficas
fig, axs = plt.subplots(4, 3, figsize=(18, 16))

# Gráfico (a): (1/3)^n
n_values = list(range(20))  # Valores de n de 0 a 19
a_n = [1/3**n for n in n_values]  # Cálculo de la sucesión
axs[0, 0].plot(n_values, a_n, '.', label='(a) Sucesión (1/3)^n')
axs[0, 0].set_title('(a) Sucesión (1/3)^n')
axs[0, 0].set_xlabel('n')
axs[0, 0].set_ylabel('a_n')
axs[0, 0].axhline(y=0, color='r', linestyle='-', label='Límite y=0')
axs[0, 0].legend()

# Gráfico (b): π^n
n_values = list(range(20))  # Valores de n de 0 a 19
a_n = [math.pi**n for n in n_values]  # Cálculo de la sucesión
axs[0, 1].plot(n_values, a_n, '.', label='(b) Sucesión π^n')
axs[0, 1].set_yscale('log')  # Usar escala logarítmica para el eje y
axs[0, 1].set_title('(b) Sucesión π^n')
axs[0, 1].set_xlabel('n')
axs[0, 1].set_ylabel('a_n')
axs[0, 1].legend()

# Gráfico (c): (3n-1)/(2n+6) con límite y=1.5
n_values = list(range(1, 60))  # Valores de n de 1 a 60
a_n = [(3*n-1)/(2*n+6) for n in n_values]  # Cálculo de la sucesión
axs[0, 2].plot(n_values, a_n, '.', label='(c) Sucesión (3n-1)/(2n+6)')
axs[0, 2].axhline(y=1.5, color='r', linestyle='-', label='Límite y=1.5')
axs[0, 2].set_title('(c) Sucesión (3n-1)/(2n+6)')
axs[0, 2].set_xlabel('n')
axs[0, 2].set_ylabel('a_n')
axs[0, 2].legend()

# Gráfico (d): cos(π*n)
n_values = list(range(20))
a_n = [math.cos(math.pi*n) for n in n_values]
axs[1, 0].plot(n_values, a_n, '.', label='(d) Sucesión cos(π*n)')
axs[1, 0].set_title('(d) Sucesión cos(π*n)')
axs[1, 0].set_xlabel('n')
axs[1, 0].set_ylabel('a_n')
axs[1, 0].legend()

# Gráfico (e): (3n^4 - 6n^3 + 1) / (5n^3 + n^2 + 2)
n_values = list(range(1, 50))
a_n = [(3*n**4 - 6*n**3 + 1) / (5*n**3 + n**2 + 2) for n in n_values]  # Cálculo de la sucesión
axs[1, 1].plot(n_values, a_n, '.', label='(e) (3n^4 - 6n^3 + 1) / (5n^3 + n^2 + 2)')
axs[1, 1].set_title('(e) Sucesión (3n^4 - 6n^3 + 1) / (5n^3 + n^2 + 2)')
axs[1, 1].set_xlabel('n')
axs[1, 1].set_ylabel('a_n')
axs[1, 1].legend()

# Gráfico (f): (2n^5 - 3n^2 + 23) / (7n^5 + 13n^4 - 12)
n_values = list(range(1, 20))
a_n = [(2*n**5 - 3*n**2 + 23)/(7*n**5 + 13*n**4 - 12) for n in n_values]
axs[1, 2].plot(n_values, a_n, '.', label='(f) (2n^5 - 3n^2 + 23) / (7n^5 + 13n^4 - 12)')
axs[1, 2].axhline(y=0.28571428571, color='r', linestyle='-', label='Límite y=0.28571428571')
axs[1, 2].set_title('(f) Sucesión (2n^5 - 3n^2 + 23) / (7n^5 + 13n^4 - 12)')
axs[1, 2].set_xlabel('n')
axs[1, 2].set_ylabel('a_n')
axs[1, 2].legend()

# Gráfico (g): (45 - 16n^2) / (13 + 5n + 6n^3)
n_values = list(range(1, 20))
a_n = [(45 - 16*n**2) / (13 + 5*n + 6*n**3) for n in n_values]
axs[2, 0].plot(n_values, a_n, '.', label='(g) (45 - 16n^2) / (13 + 5n + 6n^3)')
axs[2, 0].axhline(y=0, color='r', linestyle='-', label='Límite y=0')
axs[2, 0].set_title('(g) Sucesión (45 - 16n^2) / (13 + 5n + 6n^3)')
axs[2, 0].set_xlabel('n')
axs[2, 0].set_ylabel('a_n')
axs[2, 0].legend()

# Gráfico (h): (3n + 1) / √(4n^2 + 1)
n_values = np.linspace(1, 50, 300)  # Usamos linspace para obtener más puntos entre 1 y 50
a_n = (3*n_values + 1) / np.sqrt(4*n_values**2 + 1)
axs[2, 1].plot(n_values, a_n, '.', color='b', label='(h) Sucesión (3n+1) / √(4n^2 + 1)')
axs[2, 1].set_title('(h) Sucesión (3n+1) / √(4n^2 + 1)')
axs[2, 1].axhline(y=1.5, color='r', linestyle='-', label='Límite y=1.5')
axs[2, 1].set_xlabel('n')
axs[2, 1].set_ylabel('a_n')
axs[2, 1].legend()

# Gráfico (i): (-2)^(2n + 1)
n_values = list(range(1, 10))
a_n = [(-2)**(2*n + 1) for n in n_values]
axs[2, 2].plot(n_values, a_n, 'o', label='(i) Sucesión (-2)^(2n + 1)')
axs[2, 2].set_title('(i) Sucesión (-2)^(2n + 1)')
axs[2, 2].set_xlabel('n')
axs[2, 2].set_ylabel('a_n')
axs[2, 2].set_yscale('symlog')  # Escala logarítmica simétrica en el eje y
axs[2, 2].legend()

# Gráfico (j): (10 - 16*n^3) / (1 + n^2)
n_values = list(range(1, 50))  # Generar valores de 1 a 49
a_n = [(10 - 16*n**3) / (1 + n**2) for n in n_values]
axs[3, 0].plot(n_values, a_n, '.', color='b', label='(j) Sucesión (10 - 16*n^3) / (1 + n^2)')
axs[3, 0].set_title('(j) Sucesión (10 - 16*n^3) / (1 + n^2)')
axs[3, 0].set_xlabel('n')
axs[3, 0].set_ylabel('a_n')
axs[3, 0].legend()

# Gráfico (k): √(3*n^2 + n - 6) / √(5*n^2 + 16)
n_values = list(range(2, 50))  # Generar valores de 1 a 49
a_n = [np.sqrt(3*n**2 + n - 6) / np.sqrt(5*n**2 + 16) for n in n_values]
axs[3, 1].plot(n_values, a_n, '.', color='b', label='(k) Sucesión √(3*n^2 + n - 6) / √(5*n^2 + 16)')
axs[3, 1].set_title('(k) Sucesión (3*n^2 + n - 6) / (5*n^2 + 16)')
axs[3, 1].axhline(y=0.77459666924, color='r', linestyle='-', label='Límite y=0.77459666924')
axs[3, 1].set_xlabel('n')
axs[3, 1].set_ylabel('a_n')
axs[3, 1].legend()

# Gráfico (l): (-1)**n) / (5**n)
n_values = list(range(0, 50))  # Generar valores de 0 a 50
a_n = [((-1)**n) / (5**n) for n in n_values]
axs[3, 2].plot(n_values, a_n, '.', color='b', label='(l) Sucesión (-1)**n) / (5**n)')
axs[3, 2].set_title('(l) Sucesión (-1)**n) / (5**n)')
axs[3, 2].axhline(y=0, color='r', linestyle='-', label='Límite y=0')
axs[3, 2].set_xlabel('n')
axs[3, 2].set_ylabel('a_n')
axs[3, 2].legend()

# Ajustar el espaciado entre gráficos
plt.tight_layout()
plt.show()
